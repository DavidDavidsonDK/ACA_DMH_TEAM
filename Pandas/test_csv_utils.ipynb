# %%
from csv_utils import read_csv
import pandas as pd

# %%
dataFrame = read_csv('titanic.csv', 10)
pd.DataFrame(dataFrame)
# Out:
#             0         1       2           3   \
# 0  PassengerId  Survived  Pclass        Name
# 1            1         0       3     "braund
# 2            2         1       1    "Cumings
# 3            3         1       3  "Heikkinen
# 4            4         1       1   "Futrelle
# 5            5         0       3      "Allen
# 6            6         0       3      "Moran
# 7            7         0       1   "McCarthy
# 8            8         0       3    "Palsson
# 9            9         1       3    "Johnson
#
#                                              4       5      6      7       8   \
# 0                                           Sex     Age  SibSp  Parch  Ticket
# 1                              Mr. Owen Harris"    male     22      1       0
# 2   Mrs. John bradley (Florence briggs Thayer)"  female     38      1       0
# 3                                  Miss. Laina"  female     26      0       0
# ...
